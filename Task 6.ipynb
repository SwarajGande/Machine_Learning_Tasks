# %% [markdown]
# # Assignment for visualization using Python Matplotlib Library

# %% [raw]
# 1. Load the necessary package for plotting using pyplot from matplotlib. Example - Days(x-axis) represents 8 days and Speed represents a car’s speed. Plot a Basic line plot between days and car speed, put x axis label as days and y axis label as car speed and put title Car Speed Measurement.
#          Days=[1,2,3,4,5,6,7,8]
#
#          Speed=[60,62,61,58,56,57,46,63]

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
Days = [1,2,3,4,5,6,7,8]
Speed = [60,62,61,58,56,57,46,63]
plt.plot(Days,Speed,"r--")
plt.xlabel("Days")
plt.ylabel("Speed")
plt.title("Car Speed Measurement")
plt.show()

# %% [raw]
# 2.  Now to above car data apply some string formats  like line style example green dotted line, marker shape like +, change markersize, markerface color etc.

# %%
plt.plot(Days,Speed,"g--",marker = "o",ms= 15,linewidth =3,mec = "black",mfc = "orange")
plt.xlabel("Days")
plt.ylabel("Speed")
plt.title("Car Speed Measurement")
plt.show()

# %% [raw]
# 3.  Plot Axes Labels, Chart title, Legend, Grid in Car minimum, Maximum and average speed in 8 days.

# %%
days=[1,2,3,4,5,6,7,8]
max_speed=[80,91,92,88,77,79,76,75]
min_speed=[42,43,40,42,33,36,34,35]
avg_speed=[46,58,57,56,40,42,41,36]

# %%
plt.subplot(3,1,1)
plt.plot(days,max_speed,"g--",marker = "o",label ="Max_speed")
plt.xlabel("Days")
plt.ylabel("max_speed")
plt.title("Car Speed Measurement")
plt.legend()
plt.grid()
plt.show()
plt.subplot(3,1,2)
plt.plot(days,min_speed,"r--",marker = "o",label ="Min_speed")
plt.xlabel("Days")
plt.ylabel("min_speed")
plt.title("Car Speed Measurement")
plt.legend()
plt.grid()
plt.show()
plt.subplot(3,1,3)
plt.plot(days,avg_speed,"b--",marker = "o",label ="Avg_speed")
plt.xlabel("Days")
plt.ylabel("avg_speed")
plt.title("Car Speed Measurement")
plt.legend()
plt.grid()
plt.show()

# %% [raw]
# 4. Plotting a basic sine graph by adding more features. Adding Multiple plots by Superimposition like cosine wave.

# %%
t = np.linspace(0,5*np.pi,100)
x1 = np.sin(t)
x2 = np.cos(t)
plt.plot(t,x1,"b--",linewidth = 1.5,label = "sin")
plt.plot(t,x2,"r-",linewidth = 1.5,label = "cos")
plt.xlabel("Time")
plt.ylabel("Magnitude")
plt.legend(loc = "best",shadow = 1)
plt.show()

# %% [raw]
# 5. Plot Simple bar chart showing popularity of Programming Languages.
# Plot Multiple Bars showing Popularity and Security of major Programming Languages. Also Create Horizontal bar chart using barh function.

# %%
Languages =['Python', 'SQL', 'Java', 'C++', 'JavaScript']
Popularity = [56, 39, 34, 34, 29]
Security = [44 ,36 ,55, 50, 42]

# %%
plt.bar(Languages,Popularity,width = 0.5)
plt.show()

# %%
plt.bar(Languages,Security,width = 0.5)
plt.show()

# %%
x = np.arange(len(Languages))
plt.bar(x-0.2,Popularity,label = "Popularity",width = 0.4)
plt.bar(x+0.2,Security,label = "Security",width = 0.4)
plt.xticks(x,Languages)
plt.xlabel("Languages")
plt.ylabel("Popularity & Security")
plt.title("Popularity and Security of major programming Languages")
plt.legend(loc = "best",shadow = 1)
plt.show()

# %%
plt.barh(x-0.2,Popularity,0.4,label = "Popularity")
plt.barh(x+0.2,Security,0.4,label = "Security")
plt.yticks(x,Languages)
plt.ylabel("Languages")
plt.xlabel("Popularity & Security")
plt.title("Popularity and Security of major programming Languages")
plt.legend(loc = "best",shadow = 1)
plt.show()

# %% [raw]
# 6. Plot Histogram, We have a sample data of Students marks of various Students, we will try to plot number of Students by marks range and try to figure out how many Students are average, below-average and Excellent.

# %%
Marks = np.array([61,86,42,46,73,95,65,78,53,92,55,69,70,49,72,86,64])
Below_Average = Marks[np.logical_and(Marks >= 40,Marks < 60)]
Average = Marks[np.logical_and(Marks >= 60,Marks < 80)]
Excellent= Marks[np.logical_and(Marks >= 80,Marks < 100)]

# %%
plt.hist(Marks,color = 'orange',edgecolor = "black")
plt.xlabel("Distribution")
plt.ylabel("Marks")
plt.title("Student Marks")
plt.vlines([40,60,80,100],ymin = 0,ymax = 4,linestyle = "dashed")
plt.show()
print("Below Average Students :",Below_Average.size)
print("Average Students :",Average.size)
print("Excellent Students :",Excellent.size)
# Out:
# Below Average Students : 5
# Average Students : 8
# Excellent Students : 4

# %% [raw]
# 7. Titanic Data Set Download Data
#
#  Load the data file
#
#  (i) Create a pie chart presenting the male/female proportion
#
#  (ii) Create a scatterplot with the Fare paid and the Age, differ the plot color by gender

# %%
import pandas as pd
import seaborn as sns
df = pd.read_csv("titanic_original.csv")
df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0     1.0       1.0                    Allen, Miss. Elisabeth Walton  female
# 1     1.0       1.0                   Allison, Master. Hudson Trevor    male
# 2     1.0       0.0                     Allison, Miss. Helen Loraine  female
# 3     1.0       0.0             Allison, Mr. Hudson Joshua Creighton    male
# 4     1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000    0.0    0.0   24160  211.3375       B5        S    2    NaN
# 1   0.9167    1.0    2.0  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %%
df.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881135     0.498854     0.385027
# std       0.837836     0.486055    14.413500     1.041658     0.865560
# min       1.000000     0.000000     0.166700     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1308.000000  121.000000
# mean     33.295479  160.809917
# std      51.758668   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000

# %%
x = df["sex"].value_counts()
plt.pie(x, autopct='%.0f%%')
plt.legend(['Male','Female'])
plt.title('Male And Female Proportion')
plt.axis
plt.show()

# %%
male = df[df["sex"] == "male"]
male["sex"].value_counts()
# Out:
# male    843
# Name: sex, dtype: int64

# %%
female = df[df["sex"] == "female"]
female["sex"].value_counts()
# Out:
# female    466
# Name: sex, dtype: int64

# %%
plt.scatter(male["fare"],male["age"],label = "Male")
plt.scatter(female["fare"],female["age"],label = 'Female')
plt.legend(shadow = 1)
plt.grid()
plt.show()
