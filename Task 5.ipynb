# %%
import pandas as pd
import numpy as np

# %% [raw]
# 1. Load the IMDb Dataset and read

# %%
df = pd.read_csv("IMDB-Movie-Data.csv")

# %% [raw]
# 2. View the dataset

# %%
df.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %%
df.tail()
# Out:
#      Rank                   Title                  Genre  \
# 995   996    Secret in Their Eyes    Crime,Drama,Mystery
# 996   997         Hostel: Part II                 Horror
# 997   998  Step Up 2: The Streets    Drama,Music,Romance
# 998   999            Search Party       Adventure,Comedy
# 999  1000              Nine Lives  Comedy,Family,Fantasy
#
#                                            Description          Director  \
# 995  A tight-knit team of rising investigators, alo...         Billy Ray
# 996  Three American college students studying abroa...          Eli Roth
# 997  Romantic sparks occur between two dance studen...        Jon M. Chu
# 998  A pair of friends embark on a mission to reuni...    Scot Armstrong
# 999  A stuffy businessman finds himself trapped ins...  Barry Sonnenfeld
#
#                                                 Actors  Year  \
# 995  Chiwetel Ejiofor, Nicole Kidman, Julia Roberts...  2015
# ...

# %% [raw]
# 3. Understand some basic information about the dataset and Inspect the    dataframe Inspect the dataframe's columns, shapes, variable types etc.

# %%
df.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Rank                    int64
# Title                  object
# Genre                  object
# Description            object
# Director               object
# Actors                 object
# Year                    int64
# Runtime (Minutes)       int64
# Rating                float64
# Votes                   int64
# Revenue (Millions)    float64
# Metascore             float64
# dtype: object

# %%
df.shape
# Out:
# (1000, 12)

# %%
df.describe()    # All the Numerical statistical Data
# Out:
#               Rank         Year  Runtime (Minutes)       Rating         Votes  \
# count  1000.000000  1000.000000        1000.000000  1000.000000  1.000000e+03
# mean    500.500000  2012.783000         113.172000     6.723200  1.698083e+05
# std     288.819436     3.205962          18.810908     0.945429  1.887626e+05
# min       1.000000  2006.000000          66.000000     1.900000  6.100000e+01
# 25%     250.750000  2010.000000         100.000000     6.200000  3.630900e+04
# 50%     500.500000  2014.000000         111.000000     6.800000  1.107990e+05
# 75%     750.250000  2016.000000         123.000000     7.400000  2.399098e+05
# max    1000.000000  2016.000000         191.000000     9.000000  1.791916e+06
#
#        Revenue (Millions)   Metascore
# count          872.000000  936.000000
# mean            82.956376   58.985043
# std            103.253540   17.194757
# min              0.000000   11.000000
# 25%             13.270000   47.000000
# ...

# %% [raw]
# 4. Data Selection – Indexing and Slicing data

# %%
df[["Metascore",'Rating',"Votes"]]
# Out:
#      Metascore  Rating   Votes
# 0         76.0     8.1  757074
# 1         65.0     7.0  485820
# 2         62.0     7.3  157606
# 3         59.0     7.2   60545
# 4         40.0     6.2  393727
# ..         ...     ...     ...
# 995       45.0     6.2   27585
# 996       46.0     5.5   73152
# 997       50.0     6.2   70699
# 998       22.0     5.6    4881
# 999       11.0     5.3   12435
#
# [1000 rows x 3 columns]

# %%
df[["Metascore","Rating","Votes"]].agg(["min","max","mean","median"])
# Out:
#          Metascore  Rating        Votes
# min      11.000000  1.9000       61.000
# max     100.000000  9.0000  1791916.000
# mean     58.985043  6.7232   169808.255
# median   59.500000  6.8000   110799.000

# %% [raw]
# 5. Data Selection – Based on Conditional filtering

# %%
df_Rating = df[df["Rating"]>7]["Rating"]
df_Rating.count()
# Out:
# 399

# %% [raw]
# 399 Title are Rated above 7

# %%
df
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %% [raw]
# 6. Group by operations

# %%
df_Genre = df.groupby("Genre")
df_2 = df_Genre[["Rating","Votes"]].mean()   # Average Rating on Different Genre
df_2
# Out:
#                               Rating          Votes
# Genre
# Action                      6.150000    8618.500000
# Action,Adventure            6.400000  334459.000000
# Action,Adventure,Biography  7.000000   48780.000000
# Action,Adventure,Comedy     6.592857  193502.357143
# Action,Adventure,Crime      6.433333  200322.833333
# ...                              ...            ...
# Romance,Sci-Fi,Thriller     7.100000  208632.000000
# Sci-Fi                      4.950000     726.500000
# Sci-Fi,Thriller             5.000000  170897.000000
# Thriller                    5.955556   33960.222222
# Thriller,War                6.000000    5926.000000
#
# [207 rows x 2 columns]

# %%
print(df_2[df_2["Rating"]>7]["Rating"])  # 7 Above Rated Genre
df_2[df_2["Rating"]>7]["Rating"].count()
# Out:
# Genre
# Action,Adventure,Thriller    7.027273
# Action,Biography,Crime       7.100000
# Action,Biography,Drama       7.112500
# Action,Comedy,Mystery        7.900000
# Action,Drama,Horror          7.500000
#                                ...
# Drama,Western                8.400000
# Mystery,Romance,Sci-Fi       7.500000
# Mystery,Sci-Fi,Thriller      7.233333
# Mystery,Thriller,Western     7.100000
# Romance,Sci-Fi,Thriller      7.100000
# Name: Rating, Length: 77, dtype: float64
# 77

# %% [raw]
# 7. Sorting operation

# %%
votes = df.groupby(["Votes"]).mean()
votes.sort_values(by = ["Votes"], ascending = False).head()
# Out:
#           Rank    Year  Runtime (Minutes)  Rating  Revenue (Millions)  \
# Votes
# 1791916   55.0  2008.0              152.0     9.0              533.32
# 1583625   81.0  2010.0              148.0     8.8              292.57
# 1222645  125.0  2012.0              164.0     8.5              448.13
# 1047747   37.0  2014.0              169.0     8.6              187.99
# 1045588   77.0  2012.0              143.0     8.1              623.28
#
#          Metascore
# Votes
# 1791916       82.0
# 1583625       74.0
# 1222645       78.0
# 1047747       74.0
# 1045588       69.0

# %% [raw]
# 8. Dealing with missing values

# %%
df.isnull().sum()
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %%
df["Metascore"].mean()
# Out:
# 58.98504273504273

# %%
df["Metascore"] = df["Metascore"].fillna(df["Metascore"].mean())

# %%
df.isnull().sum()
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore               0
# dtype: int64

# %%
df["Revenue (Millions)"].mean()
# Out:
# 82.95637614678897

# %%
df["Revenue (Millions)"] = df["Revenue (Millions)"].fillna(df["Revenue (Millions)"].mean())

# %%
df.isnull().sum()
# Out:
# Rank                  0
# Title                 0
# Genre                 0
# Description           0
# Director              0
# Actors                0
# Year                  0
# Runtime (Minutes)     0
# Rating                0
# Votes                 0
# Revenue (Millions)    0
# Metascore             0
# dtype: int64

# %% [raw]
# 9. Dropping columns and null values

# %%
df1 = df.dropna()   #Drops all the Rows and columns with any Null Values
df1
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %% [raw]
# 10. Apply() functions

# %%
rank = df.apply(lambda n: n*5)
rank.head()
# Out:
#    Rank                                              Title  \
# 0     5  Guardians of the GalaxyGuardians of the Galaxy...
# 1    10  PrometheusPrometheusPrometheusPrometheusPromet...
# 2    15                          SplitSplitSplitSplitSplit
# 3    20                               SingSingSingSingSing
# 4    25  Suicide SquadSuicide SquadSuicide SquadSuicide...
#
#                                                Genre  \
# 0  Action,Adventure,Sci-FiAction,Adventure,Sci-Fi...
# 1  Adventure,Mystery,Sci-FiAdventure,Mystery,Sci-...
# 2  Horror,ThrillerHorror,ThrillerHorror,ThrillerH...
# 3  Animation,Comedy,FamilyAnimation,Comedy,Family...
# 4  Action,Adventure,FantasyAction,Adventure,Fanta...
#
#                                          Description  \
# 0  A group of intergalactic criminals are forced ...
# 1  Following clues to the origin of mankind, a te...
# 2  Three girls are kidnapped by a man with a diag...
# 3  In a city of humanoid animals, a hustling thea...
# ...
